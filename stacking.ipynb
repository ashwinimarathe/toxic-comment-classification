# %%
import pandas as pd
import numpy as np

# %%
nb_svm = pd.read_csv('nb_svm.csv')
glove = pd.read_csv('glove_embeddings.csv')

# %%
labels = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

# %%
stacking = nb_svm.copy()
stacking[labels] = 0.5*nb_svm[labels] + 0.5*glove[labels]

# %%
stacking
# Out:
#                       id     toxic  severe_toxic   obscene    threat  \
# 0       00001cee341fdb12  6.158006     -0.807399  6.108695 -2.973994
# 1       0000247867823ef7 -2.925233     -3.719349 -3.135949 -4.664537
# 2       00013b17ad220c46 -2.215327     -3.538934 -2.592176 -4.655510
# 3       00017563c3f7919a -3.473456     -4.210500 -3.387810 -4.380944
# 4       00017695ad8997eb -2.299604     -3.837878 -3.107943 -4.537113
# ...                  ...       ...           ...       ...       ...
# 153159  fffcd0960ee309b5  0.473718     -4.064605 -1.205825 -4.556586
# 153160  fffd7a9a6eb32c16 -2.002364     -3.438266 -1.948341 -3.418184
# 153161  fffda9e8d6fafa9e -3.290013     -4.387946 -2.960918 -4.781028
# 153162  fffe8f1340a79fc2 -2.410270     -4.010703 -3.047110 -4.677053
# 153163  ffffce3fb183ee80  1.917572     -4.517041  0.299573 -4.019596
#
#           insult  identity_hate
# 0       2.079663      -0.878089
# 1      -3.054572      -4.007128
# 2      -2.870671      -4.076459
# ...

# %%
stacking.to_csv('stacking.csv')

# %%
stacking1 = pd.read_csv
# Out:
#                       id      toxic  severe_toxic    obscene    threat  \
# 0       00001cee341fdb12  11.319053     -2.098291  11.234021 -6.055280
# 1       0000247867823ef7  -5.850832     -7.438699  -6.272031 -9.329076
# 2       00013b17ad220c46  -4.432668     -7.077877  -5.184764 -9.311043
# 3       00017563c3f7919a  -6.947551     -8.421002  -6.775776 -8.761891
# 4       00017695ad8997eb  -4.601826     -7.675764  -6.216359 -9.074248
# ...                  ...        ...           ...        ...       ...
# 153159  fffcd0960ee309b5   0.350358     -8.131433  -2.622221 -9.118213
# 153160  fffd7a9a6eb32c16  -4.007803     -6.876547  -3.897460 -6.836403
# 153161  fffda9e8d6fafa9e  -6.580492     -8.775894  -5.921979 -9.562060
# 153162  fffe8f1340a79fc2  -4.822435     -8.021413  -6.094438 -9.354136
# 153163  ffffce3fb183ee80   2.858300     -9.084315  -0.286886 -8.049924
#
#           insult  identity_hate
# 0       3.251624      -2.251894
# 1      -6.109203      -8.014266
# ...
